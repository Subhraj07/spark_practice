# %% [markdown]
# https://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/

# %%
import tweepy
from tweepy import OAuthHandler
import json
 
consumer_key = "R0tlKOjEweXN3C7gnJybze3QT"
consumer_secret = "mqABPsPARcaSlPkIxahON8lByYdSQLqXHlIKxg4TN6VVGrXCDZ"
access_token = "4213925472-jDCJfJgXinnUeiTQuL91X09qELTHIjY2y85iSMb"
access_secret = "lruiciXrJJ6Xj3wt9OvoVatsTYYKqAxFlzuW4arml6BMw"
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    print(status.text)
# Out:
# RT @TechGeekRebel: The details do always matter, the details make the design! 🔦
# #tech #science #bigdata #mobile #innovation #awesome #start…
# The Magic of #datascience in #Marketing https://t.co/O3QfglYaOV https://t.co/EKGnD6KrLF
# PRESS RELEASE » Global Cloud Infrastructure Services Market Industry Growth, Share, Demand, Size and Applications, Key Players, Forecast to…
# RT @ThePracticalDev: Using git bisect
# { author: @gonedark }
# https://t.co/fV6UT8kwoI
# Come to Chief Analytics Officer Spring 2017 on 2 May, get 15% off with code MP15 #caospring
#
# https://t.co/lmZ5ME2LbJ
# Top Machine Learning @rightrelevance experts (https://t.co/yfMIlnSUOb) to follow https://t.co/nX7XoUw39K
# Continuous Queries on Dynamic Tables: Analyzing Data Streams with SQL https://t.co/cuDbfKV9Qe #bigdata #flink via… https://t.co/ypuL8s546p
# Special Edition Data Science Interview Questions Solved In Python And Spark: With De here  https://t.co/tYLmrC1bIY #bigdata @machinelearnbot
# ...

# %%
def process_or_store(tweet):
    print(json.dumps(tweet))

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    process_or_store(status._json)
# Out:
# {"created_at": "Tue Apr 18 08:21:14 +0000 2017", "id": 854248440968228866, "id_str": "854248440968228866", "text": "RT @TechGeekRebel: The details do always matter, the details make the design! \ud83d\udd26\n#tech #science #bigdata #mobile #innovation #awesome #start\u2026", "truncated": false, "entities": {"hashtags": [{"text": "tech", "indices": [80, 85]}, {"text": "science", "indices": [86, 94]}, {"text": "bigdata", "indices": [95, 103]}, {"text": "mobile", "indices": [104, 111]}, {"text": "innovation", "indices": [112, 123]}, {"text": "awesome", "indices": [124, 132]}], "symbols": [], "user_mentions": [{"screen_name": "TechGeekRebel", "name": "TECH|GEEK|REBEL", "id": 3240325433, "id_str": "3240325433", "indices": [3, 17]}], "urls": []}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "u
# ...

# %%
for friend in tweepy.Cursor(api.friends).items():
    process_or_store(friend._json)
# Out:
# {"id": 56738301, "id_str": "56738301", "name": "SearchDataManagement", "screen_name": "sDataManagement", "location": "Newton, MA", "description": "TechTarget\u2019s resource on data warehousing, Hadoop and big data management, data integration, data quality and more. Tweets from editor Jack I Vaughan.", "url": "http://t.co/ksGtSkeqFZ", "entities": {"url": {"urls": [{"url": "http://t.co/ksGtSkeqFZ", "expanded_url": "http://searchdatamanagement.techtarget.com", "display_url": "searchdatamanagement.techtarget.com", "indices": [0, 22]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 3090, "friends_count": 741, "listed_count": 352, "created_at": "Tue Jul 14 16:20:10 +0000 2009", "favourites_count": 19, "utc_offset": -14400, "time_zone": "Eastern Time (US & Canada)", "geo_enabled": false, "verified": false, "statuses_count": 4893, "lang": "en", "status": {"created_at": "Sun Apr 16 20:00:01 +0000 2017", "id": 853699521251069954, "id_str": "853699521251069954", "text"
# ...

# %%
for tweet in tweepy.Cursor(api.user_timeline).items():
    process_or_store(tweet._json)
# Out:
# {"created_at": "Wed Feb 15 19:48:05 +0000 2017", "id": 831953245064933377, "id_str": "831953245064933377", "text": "RT @apachespark_tc: Join our Webinar: An Introduction to #ApacheSpark Structured Streaming #SparkStreaming https://t.co/I1uCDfxkPo https://\u2026", "truncated": false, "entities": {"hashtags": [{"text": "ApacheSpark", "indices": [57, 69]}, {"text": "SparkStreaming", "indices": [91, 106]}], "symbols": [], "user_mentions": [{"screen_name": "apachespark_tc", "name": "Spark Tech Center", "id": 3295588728, "id_str": "3295588728", "indices": [3, 18]}], "urls": [{"url": "https://t.co/I1uCDfxkPo", "expanded_url": "http://bit.ly/2jdqnRA", "display_url": "bit.ly/2jdqnRA", "indices": [107, 130]}]}, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 421392547
# ...

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

keyword = "spark"
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('.\\stream_tweet\\%s_stream.json' % keyword, 'a') as f:
                f.write(data)
                print(len(data))
                return True
        except BaseException as e:
            print("Error on_data:  %s " % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#' + keyword])

# %% [markdown]
# ###### Getting the data for a given user

# %%
import tweepy 
import csv

#Twitter API credentials
consumer_key = "R0tlKOjEweXN3C7gnJybze3QT"
consumer_secret = "mqABPsPARcaSlPkIxahON8lByYdSQLqXHlIKxg4TN6VVGrXCDZ"
access_key = "4213925472-jDCJfJgXinnUeiTQuL91X09qELTHIjY2y85iSMb"
access_secret = "lruiciXrJJ6Xj3wt9OvoVatsTYYKqAxFlzuW4arml6BMw"


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)

    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1

    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print("getting tweets before %s" % (oldest))
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)

        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print("...%s tweets downloaded so far" % (len(alltweets)))
    
    #transform the tweepy tweets into a 2D array that will populate the csv	
    #outtweets = [[tweet.id_str, tweet.created_at,tweet.place,tweet.user, tweet.text.encode("utf-8")] for tweet in alltweets]
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    
    #write the csv	
    with open('.\\user_tweet\\%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)
    
    pass


if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("GrantThorntonUS")
# Out:
# getting tweets before 846363409276964863
# ...400 tweets downloaded so far
# getting tweets before 836689959985651712
# ...600 tweets downloaded so far
# getting tweets before 823534570435997696
# ...800 tweets downloaded so far
# getting tweets before 809164865881382911
# ...1000 tweets downloaded so far
# getting tweets before 799616560444952576
# ...1200 tweets downloaded so far
# getting tweets before 788899617295503359
# ...1400 tweets downloaded so far
# getting tweets before 778979738761170943
# ...1599 tweets downloaded so far
# getting tweets before 766636420924575743
# ...1799 tweets downloaded so far
# getting tweets before 758307637532454911
# ...1999 tweets downloaded so far
# getting tweets before 745338895416565759
# ...2199 tweets downloaded so far
# getting tweets before 738466022328410111
# ...2399 tweets downloaded so far
# getting tweets before 726885201020903423
# ...2599 tweets downloaded so far
# getting tweets before 717021474947743745
# ...

# %% [markdown]
# ###### Sentiment twitter

# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
 
class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = "R0tlKOjEweXN3C7gnJybze3QT"
        consumer_secret = "mqABPsPARcaSlPkIxahON8lByYdSQLqXHlIKxg4TN6VVGrXCDZ"
        access_token = "4213925472-jDCJfJgXinnUeiTQuL91X09qELTHIjY2y85iSMb"
        access_token_secret = "lruiciXrJJ6Xj3wt9OvoVatsTYYKqAxFlzuW4arml6BMw"
      
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
 
        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)
 
            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}
 
                # saving text of tweet
                parsed_tweet['text'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)
 
            # return parsed tweets
            return tweets
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))
 
def main():
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query = 'GrantThorntonUS', count = 200)
 
    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    #print("Neutral tweets percentage: {} %".format(100*len(tweets - ntweets - ptweets)/len(tweets)))
 
    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:10]:
        print(tweet['text'])
 
    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:10]:
        print(tweet['text'])
 
if __name__ == "__main__":
    # calling main function
    main()
# Out:
# Positive tweets percentage: 39.77272727272727 %
# Negative tweets percentage: 5.681818181818182 %
#
#
# Positive tweets:
# RT @GrantThorntonUS: There’s more to #riskmanagement than #cybersecurity.  Where #CFOs are focusing priorities &gt;&gt; https://t.co/7MNcgsk2zK h…
# Best accounting firms to work for #STL Congrats @PwC_LLP @Deloitte @EYnews @KPMG_US @GrantThorntonUS @bswllc… https://t.co/YhGXr6UU38
# There’s more to #riskmanagement than #cybersecurity.  Where #CFOs are focusing priorities &gt;&gt; https://t.co/7MNcgsk2zK https://t.co/pdrvOVN73r
# RT @CrainsChicago: Crain's Best Places to Work in Chicago:
#
# —@StratosphereNet
# —@AssuranceATeam
# —@RadioFlyer
# —@GrantThorntonUS
#
# &amp; more: http…
# #Midmarket tip: For best-in-class working capital management, watch payables, receivables, inventory + digitization&gt;&gt;https://t.co/6EUvqVfiFq
# Steps to finding the right volunteers for your #nonprofit. Via @GrantThorntonUS https://t.co/maBqRqcl4L https://t.co/DywLr9ZJyf
# ...
