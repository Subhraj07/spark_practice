# %%
import csv
import requests
import xml.etree.ElementTree as ET
 
def loadRSS():
 
    # url of rss feed
#     url = 'http://www.hindustantimes.com/rss/topnews/rssfeed.xml'
    url = 'http://www.user-agents.org/allagents.xml'
 
    # creating HTTP response object from given url
    resp = requests.get(url)
 
    # saving the xml file
    with open('topnewsfeed.xml', 'wb') as f:
        f.write(resp.content)
        

def parseXML(xmlfile):
 
    # create element tree object
    tree = ET.parse(xmlfile)
 
    # get root element
    root = tree.getroot()
 
    # create empty list for news items
    newsitems = []
 
    # iterate news items
    for item in root.findall('./channel/item'):
 
        # empty news dictionary
        news = {}
 
        # iterate child elements of item
        for child in item:
 
            # special checking for namespace object content:media
            if child.tag == '{http://search.yahoo.com/mrss/}content':
                news['media'] = child.attrib['url']
            else:
                news[child.tag] = child.text.encode('utf8')
 
        # append news dictionary to news items list
        newsitems.append(news)
     
    # return news items list
    return newsitems
 

def savetoCSV(newsitems, filename):
 
    # specifying the fields for csv file
    fields = ['guid', 'title', 'pubDate', 'description', 'link', 'media']
 
    # writing to csv file
    with open(filename, 'w') as csvfile:
 
        # creating a csv dict writer object
        writer = csv.DictWriter(csvfile, fieldnames = fields)
 
        # writing headers (field names)
        writer.writeheader()
 
        # writing data rows
        writer.writerows(newsitems)
 
     
def main():
    # load rss from web to update existing xml file
    loadRSS()
 
    # parse xml file
    newsitems = parseXML('topnewsfeed.xml')
 
    # store news items in a csv file
    savetoCSV(newsitems, 'topnews.csv')
     
if __name__ == "__main__":
 
    # calling main function
    main()

# %%
xml_data = open('topnewsfeed.xml').read() #Loading the raw XML data

def xml2df(xml_data):
    root = ET.XML(xml_data) # element tree
    all_records = [] #This is our record list which we will convert into a dataframe
    for i, child in enumerate(root): #Begin looping through our root tree
        record = {} #Place holder for our record
        for subchild in child: #iterate through the subchildren to user-agent, Ex: ID, String, Description.
            record[subchild.tag] = subchild.text #Extract the text create a new dictionary key, value pair
            all_records.append(record) #Append this record to all_records.
    return pd.DataFrame(all_records) #return records as DataFrame

# %%
import pandas as pd
data = xml2df(xml_data)

# %%
root = ET.XML(xml_data)
for i, child in enumerate(root):
    for subchild in child:
        print(subchild.tag)
# Out:
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# Description
# Type
# Comment
# Link1
# Link2
# ID
# String
# ...

# %%
import xml.etree.ElementTree as ET
xml_data = open('./xml_files/demo1.xml').read() #Loading the raw XML data

def xml2df(xml_data):
    root = ET.XML(xml_data) # element tree
    all_records = [] #This is our record list which we will convert into a dataframe
    for i, child in enumerate(root): #Begin looping through our root tree
        record = {} #Place holder for our record
        for subchild in child: #iterate through the subchildren to user-agent, Ex: ID, String, Description.
            record[subchild.tag] = subchild.text #Extract the text create a new dictionary key, value pair
            all_records.append(record) #Append this record to all_records.
    return pd.DataFrame(all_records) #return records as DataFrame

# %%
data = xml2df(xml_data)

# %%
def xml2df(xml_data):
    root = ET.XML(xml_data) # element tree
    all_records = [] #This is our record list which we will convert into a dataframe
    for i, child in enumerate(root): #Begin looping through our root tree
        record = {} #Place holder for our record
        for subchild in child: #iterate through the subchildren to user-agent, Ex: ID, String, Description.
            record[subchild.tag] = subchild.text #Extract the text create a new dictionary key, value pair
            all_records.append(record) #Append this record to all_records.
    return all_records #return records as DataFrame

# %%
import glob
import errno
path = './xml_files/*.xml'
files = glob.glob(path)
xml_file = []
for name in files:
    xml_file.append(name)

# %%
# xml_records = []
# for x in xml_file:
#     root = ET.XML(x)
# #     xml_records.append(xml2df(x))

# %%
xml_data = open('topnewsfeed.xml').read() #Loading the raw XML data
root = ET.XML(xml_data)
root
# Out:
# <Element 'user-agents' at 0x0000000008342A48>

# %%
import os

path = './xml_files'
for filename in os.listdir(path):
    if not filename.endswith('.xml'): continue
    fullname = os.path.join(path, filename)
    tree = ET.parse(fullname) 
    print(tree)

# %%
import xml.etree.ElementTree as ET
import os
import pandas as pd

path = './xml_files/test'
all_records = [] #This is our record list which we will convert into a dataframe
record = {} #Place holder for our record
for filename in os.listdir(path):
    if not filename.endswith('.xml'): continue
    fullname = os.path.join(path, filename)
    fullname = open(fullname).read()
    root = ET.XML(fullname)
    for i, child in enumerate(root): #Begin looping through our root tree
        for subchild in child: #iterate through the subchildren to user-agent, Ex: ID, String, Description.
            record[subchild.tag] = subchild.text #Extract the text create a new dictionary key, value pair
#             print(record)
            
all_records.append(record) #Append this record to all_records.
data = pd.DataFrame(all_records)

# %%
data
# Out:
#   Comment                                      Description        ID  \
# 0    None  Sync2It bookmark management & clustering engine  id_a_f_3
#
#                     Link1 Link2                                 String Type
# 0  http://www.sync2it.com  None  !Susie (http://www.sync2it.com/susie)  C R

# %%
import xml.etree.ElementTree as ET
import os
import pandas as pd

path = './xml_files'
all_records = [] #This is our record list which we will convert into a dataframe
record = {} #Place holder for our record
for filename in os.listdir(path):
    if not filename.endswith('.xml'): continue
    fullname = os.path.join(path, filename)
    fullname = open(fullname).read()
    root = ET.XML(fullname)
    for i, child in enumerate(root): #Begin looping through our root tree
        for subchild in child: #iterate through the subchildren to user-agent, Ex: ID, String, Description.
            record[subchild.tag] = subchild.text #Extract the text create a new dictionary key, value pair
        print(record)
        all_records.append(record.copy())
#     print(all_records)
#         print(all_records)
# all_records.append(record) #Append this record to all_records.
# data = pd.DataFrame(all_records)
# Out:
# {'ID': 'id_a_f_3', 'String': '!Susie (http://www.sync2it.com/susie)', 'Description': 'Sync2It bookmark management & clustering engine', 'Type': 'C R', 'Comment': None, 'Link1': 'http://www.sync2it.com', 'Link2': None}
# {'ID': 'id_a_f_6', 'String': "<a href='http://www.unchaos.com/'> UnChaos </a> From Chaos To Order Hybrid Web Search Engine.(vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.unchaos.com/', 'Link2': None}
# {'ID': 'id_a_f_7', 'String': "<a href='http://www.unchaos.com/'> UnChaos Bot Hybrid Web Search Engine. </a> (vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.unchaos.com/', 'Link2': None}
# ...

# %%
current_dict = {'corse': 378, 'cielo': 209, 'mute': 16}
print(current_dict)
def replace_value_with_definition(key_to_find, definition):
    for key in current_dict.keys():
        if key == key_to_find:
            current_dict[key] = definition

replace_value_with_definition('corse', 'Definition of "corse"')
print(current_dict)
# Out:
# {'corse': 378, 'cielo': 209, 'mute': 16}
# {'corse': 'Definition of "corse"', 'cielo': 209, 'mute': 16}

# %%
la = [
    {'ID': 'id_a_f_3', 'String': '!Susie (http://www.sync2it.com/susie)', 'Description': 'Sync2It bookmark management & clustering engine', 'Type': 'C R', 'Comment': None, 'Link1': 'http://www.sync2it.com', 'Link2': None}
    {'ID': 'id_a_f_6', 'String': "<a href='http://www.unchaos.com/'> UnChaos </a> From Chaos To Order Hybrid Web Search Engine.(vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.unchaos.com/', 'Link2': None}
    {'ID': 'id_a_f_7', 'String': "<a href='http://www.unchaos.com/'> UnChaos Bot Hybrid Web Search Engine. </a> (vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.unchaos.com/', 'Link2': None}
    {'ID': 'id_a_f_8', 'String': '<b> UnChaosBot From Chaos To Order UnChaos Hybrid Web Search Engine at www.unchaos.com </b> (info@unchaos.com)', 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.unchaos.com/', 'Link2': None}
    {'ID': 'id_a_f_9', 'String': '<http://www.sygol.com/> http://www.sygol.com', 'Description': 'Sygol Search (Italy) robot', 'Type': 'R', 'Comment': 's.also SygolBot', 'Link1': 'http://www.sygol.com/', 'Link2': None}
    {'ID': 'id_a_f_4', 'String': '( Robots.txt Validator http://www.searchengineworld.com/cgi-bin/robotcheck.cgi )', 'Description': "SearchEngineWorld's robots.txt validator", 'Type': 'C', 'Comment': 'Services is no more available', 'Link1': 'http://www.searchengineworld.com/cgi-bin/robotcheck.cgi', 'Link2': None}
    {'ID': 'id_a_f_171105_1', 'String': '(DreamPassport/3.0; isao/MyDiGiRabi)', 'Description': 'DreamCast DreamPassport browser', 'Type': 'B', 'Comment': None, 'Link1': 'http://www.dricas.com/dp/', 'Link2': None}
    {'ID': 'id_a_f_290606_1', 'String': '(Privoxy/1.0)', 'Description': 'Privoxy web proxy', 'Type': 'P', 'Comment': 's.also Privoxy/3.0 (Anonymous)', 'Link1': 'http://www.privoxy.org/', 'Link2': None}
    {'ID': 'id_a_f_230507_1', 'String': '*/Nutch-0.9-dev', 'Description': 'Unknown Yahoo robot', 'Type': 'R', 'Comment': '123.113.184.2xx', 'Link1': 'http://www.yahoo.com', 'Link2': None}
    {'ID': 'id_a_f_5', 'String': '+SitiDi.net/SitiDiBot/1.0 (+Have Good Day)', 'Description': 'SitiDi.net search (Germany) robot', 'Type': 'R', 'Comment': None, 'Link1': 'http://www.sitidi.net/', 'Link2': None}
    {'ID': 'id_a_f_1', 'String': '-DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www.die-kraehe.de', 'Description': 'Die Kraehe Meta-Search-Engine (Germany) link checking', 'Type': 'R', 'Comment': None, 'Link1': 'http://www.die-kraehe.de', 'Link2': None}
    {'ID': 'id_a_f_060206_1', 'String': '123spider-Bot (Version: 1.02, powered by www.123spider.de', 'Description': '123spider.de (Germany) web directory link checking', 'Type': 'C', 'Comment': None, 'Link1': 'http://www.123spider.de/', 'Link2': None}
    {'ID': 'id_a_f_180806_1', 'String': '192.comAgent', 'Description': '192.com - UK web directory', 'Type': 'R', 'Comment': '217.160.75.2xx', 'Link1': 'http://www.192.com/', 'Link2': None}
    {'ID': 'id_a_f_060606_1', 'String': '1st ZipCommander (Net) - http://www.zipcommander.com/', 'Description': '1st ZipCommander Net - IE based browser', 'Type': 'B', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
]
lb = [
    {'ID': 'id_a_f_3', 'String': '!Susie (http://www.sync2it.com/susie)', 'Description': 'Sync2It bookmark management & clustering engine', 'Type': 'C R', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_6', 'String': "<a href='http://www.unchaos.com/'> UnChaos </a> From Chaos To Order Hybrid Web Search Engine.(vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_7', 'String': "<a href='http://www.unchaos.com/'> UnChaos Bot Hybrid Web Search Engine. </a> (vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_8', 'String': '<b> UnChaosBot From Chaos To Order UnChaos Hybrid Web Search Engine at www.unchaos.com </b> (info@unchaos.com)', 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_9', 'String': '<http://www.sygol.com/> http://www.sygol.com', 'Description': 'Sygol Search (Italy) robot', 'Type': 'R', 'Comment': 's.also SygolBot', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_4', 'String': '( Robots.txt Validator http://www.searchengineworld.com/cgi-bin/robotcheck.cgi )', 'Description': "SearchEngineWorld's robots.txt validator", 'Type': 'C', 'Comment': 'Services is no more available', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_171105_1', 'String': '(DreamPassport/3.0; isao/MyDiGiRabi)', 'Description': 'DreamCast DreamPassport browser', 'Type': 'B', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_290606_1', 'String': '(Privoxy/1.0)', 'Description': 'Privoxy web proxy', 'Type': 'P', 'Comment': 's.also Privoxy/3.0 (Anonymous)', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_230507_1', 'String': '*/Nutch-0.9-dev', 'Description': 'Unknown Yahoo robot', 'Type': 'R', 'Comment': '123.113.184.2xx', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_5', 'String': '+SitiDi.net/SitiDiBot/1.0 (+Have Good Day)', 'Description': 'SitiDi.net search (Germany) robot', 'Type': 'R', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_1', 'String': '-DIE-KRAEHE- META-SEARCH-ENGINE/1.1 http://www.die-kraehe.de', 'Description': 'Die Kraehe Meta-Search-Engine (Germany) link checking', 'Type': 'R', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_060206_1', 'String': '123spider-Bot (Version: 1.02, powered by www.123spider.de', 'Description': '123spider.de (Germany) web directory link checking', 'Type': 'C', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_180806_1', 'String': '192.comAgent', 'Description': '192.com - UK web directory', 'Type': 'R', 'Comment': '217.160.75.2xx', 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
    {'ID': 'id_a_f_060606_1', 'String': '1st ZipCommander (Net) - http://www.zipcommander.com/', 'Description': '1st ZipCommander Net - IE based browser', 'Type': 'B', 'Comment': None, 'Link1': 'http://www.zipcommander.com/', 'Link2': None}
]
# Out:
#   File "<ipython-input-83-40f755ca11d6>", line 3
#     {'ID': 'id_a_f_6', 'String': "<a href='http://www.unchaos.com/'> UnChaos </a> From Chaos To Order Hybrid Web Search Engine.(vadim_gonchar@unchaos.com)", 'Description': 'UnCHAOS search robot', 'Type': 'R', 'Comment': 'Site is dead', 'Link1': 'http://www.unchaos.com/', 'Link2': None}
#     ^
# SyntaxError: invalid syntax
