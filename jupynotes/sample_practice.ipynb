# %% [markdown]
# https://github.com/minimaxir/facebook-page-post-scraper/blob/master/examples/how_to_build_facebook_scraper.ipynb

# %%
import pandas as pd

# %%
wallmart = pd.read_csv("walmart_facebook_statuses.csv", encoding = "ISO-8859-1")
wallmart.columns.values
# Out:
# array(['status_id', 'status_message', 'link_name', 'status_type',
#        'status_link', 'status_published', 'num_likes', 'num_comments',
#        'num_shares'], dtype=object)

# %%
wallmart[wallmart['status_id'].notnull()]
# Out:
#                             status_id  \
# 1      159616034235_10155374811059236
# 3      159616034235_10155374551839236
# 5      159616034235_10155374399619236
# 7      159616034235_10155374336919236
# 9      159616034235_10155374253684236
# 11     159616034235_10155374225659236
# 13     159616034235_10155374225454236
# 15     159616034235_10155374224559236
# 17     159616034235_10155374196914236
# 19     159616034235_10155374177419236
# 21     159616034235_10155374121754236
# 23     159616034235_10155374118959236
# 25     159616034235_10155374110534236
# 27     159616034235_10155374102084236
# 29     159616034235_10155374096609236
# 31     159616034235_10155374047999236
# 33     159616034235_10155374037829236
# 35     159616034235_10155373957329236
# 37     159616034235_10155373940899236
# 39     159616034235_10155373910239236
# 41       159616034235_217889985362501
# 43     159616034235_10155373749094236
# 45     159616034235_10155373688844236
# ...

# %%
import dateutil.parser
yourdate = dateutil.parser.parse("2017-04-17T06:00:08+0000")

# %%
yourdate.date()
# Out:
# datetime.date(2017, 4, 17)

# %%
datetime(2015, 1, 1).date() < datetime.date(2017,4,17)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-416a11e7851e> in <module>()
# ----> 1 datetime(2015, 1, 1).date()<datetime.date(2017,4,17)
#
# TypeError: descriptor 'date' requires a 'datetime.datetime' object but received a 'int'

# %%
import datetime
import pytz  # 3rd party: $ pip install pytz

u = datetime.datetime.utcnow()
u = u.replace(tzinfo=pytz.utc) #NOTE: it works only with a fixed utc offset

print(u.astimezone(pytz.timezone("America/New_York")))

#!/usr/bin/env python
from datetime import datetime
import pytz # $ pip install pytz

print(datetime.now(pytz.timezone("America/New_York")))
# Out:
# 2017-04-17 04:57:02.610063-04:00
# 2017-04-17 04:57:02.772596-04:00

# %%
datetime(2017, 4, 17)
# Out:
# datetime.datetime(2017, 4, 17, 0, 0)

# %%
datetime(2016, 8, 25).date()
# Out:
# datetime.date(2016, 8, 25)

# %%
dateutil.parser.parse("2017-04-17 04:00:15").date()
# Out:
# datetime.date(2017, 4, 17)

# %%
import tweetpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-fa525a74ba02> in <module>()
# ----> 1 import tweetpy
#
# ModuleNotFoundError: No module named 'tweetpy'
